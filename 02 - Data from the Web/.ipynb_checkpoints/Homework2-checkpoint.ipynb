# %%
import requests
from bs4 import BeautifulSoup
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Question 1

# %% [markdown]
# Definition of some constant URLs

# %%
TOP_UNIV_BASE = "https://www.topuniversities.com"
TOP_UNIV_WEBSITE = "https://www.topuniversities.com/university-rankings/world-university-rankings/2018"
# This is the file containing the general informations about university in the topuniversities website.
TOP_UNIV_DATA_INDICATOR = "https://www.topuniversities.com/sites/default/files/qs-rankings-data/357051_indicators.txt"

# %% [markdown]
# We get the file containing information about the universities

# %%
data_indicator = requests.get(TOP_UNIV_DATA_INDICATOR)

indicator_data = json.loads(data_indicator.text)

# %% [markdown]
# Definition of utility functions:
# parse_int is juste a small helper function to parse integers.
# get_university_info_from_indicator retrieve the detail data for each universit listed in the file. We return these details in a list

# %%
# Utility function to parse integers
def parse_int(string):
    tmp = string.replace(',', '')
    return int(tmp)

# For each university entry in the indicator file, we get the detail of the university.
# This method returns a list with every information requested
def get_university_info_from_indicator(raw_university):
    overview_soup = BeautifulSoup(raw_university["uni"], 'html.parser')    
    
    name = overview_soup.a.text
    rank = raw_university["overall_rank"]
    region = raw_university["region"]
    country = raw_university["location"]
    
    # Append
    details_request = requests.get(TOP_UNIV_BASE + "/" +  overview_soup.a.attrs['href'])
    details_soup = BeautifulSoup(details_request.text, 'html.parser')
    
    try:      
        total_staff = parse_int(details_soup.find("div", {"class": "total faculty"}).find("div", {"class" : "number"}).text)
        inter_staff = parse_int(details_soup.find("div", {"class": "inter faculty"}).find("div", {"class" : "number"}).text)
        total_students = parse_int(details_soup.find("div", {"class": "total student"}).find("div", {"class": "number"}).text)
        inter_students = parse_int(details_soup.find("div", {"class": "total inter"}).find("div", {"class": "number"}).text)
    except:
        total_staff = np.nan
        inter_staff = np.nan
        total_students = np.nan
        inter_students = np.nan
        
    return [name, rank, country, region, inter_staff, total_staff, inter_students, total_students]

# %% [markdown]
# Here is the main loop used to get all the informations about all the universities using the functions declared before.

# %%
# The main loop, for each university in the indicator file.
univ_list = []

for i, raw_university in enumerate(indicator_data["data"][0:200]):
    print(i, end="\r")
    univ_list.append(get_university_info_from_indicator(raw_university))
    
        
top_univ_df = pd.DataFrame(univ_list, columns=["name", "rank", "country", "region", "inter_staff", "total_staff", "inter_students", "total_students"])
# Out:
# 199

# %% [markdown]
# we decided to store the dataframe in a csv file for not having to reload it at each time we restart the kernel.

# %%
top_univ_df = pd.read_csv("top_univ_df.csv", index_col=False, usecols=range(1, 9))

# %% [markdown]
# Here we define a function to be able to add a column in a copy of our, for instance a new column could be the one which represents the ratio of international students.

# %%
def append_column_to_dataframe(dataframe, column, column_name):
    output_df = dataframe.copy()
    output_df.loc[:, column_name] = column
    return output_df

# %% [markdown]
# Let's then define a function that allow us to sort the universities with relation to a certain column in an ascending or descending order and plot the n first result in a bar plot

# %%
def print_best_university_with_ratio(df, column, title, ascending=True, n=10): 
    sorted_df = df.sort_values(column, ascending=ascending)
    sorted_df.set_index("name").loc[:, column].head(n).plot(kind="bar", title=title, figsize=(15, 10))
    plt.ylabel(column)
    plt.show()

# %% [markdown]
# And a function that aggregate universities and plot the best result of each group in a bar plot

# %%
def print_best_university_with_ratio_grouped(df_grouped, group_name, column, take_min, title):
    lambda_min = lambda x: x[x[column] == x[column].min()]
    lambda_max = lambda x: x[x[column] == x[column].max()]
    
    best_by_group = df_grouped.apply(lambda_min if take_min else lambda_max).reset_index(1).drop("level_1", 1).sort_values(column, ascending=take_min)
    best_by_group.loc[:, column].plot(kind="bar", title=title, figsize=(15, 10), )
    plt.ylabel(column)
    plt.show()

# %% [markdown]
# We can now use the function defined before to add the sudent/member ratio and the international student ratio

# %%
members_to_studends_ratio = top_univ_df.total_students / top_univ_df.total_staff
top_univ_df_with_ratio_a = append_column_to_dataframe(top_univ_df, members_to_studends_ratio, "student_faculty_ratio")

inter_students_ratio = top_univ_df.inter_students / top_univ_df.total_students
top_univ_df_with_ratios = append_column_to_dataframe(top_univ_df_with_ratio_a, inter_students_ratio, "inter_students_ratio")

# %% [markdown]
# Once it's done, we can plot all the graphs:
# - best universities in terms of students per faculty member
# - best universities in terms of international students
# - best countries ranked in terms of their university having the best student per faculty member ratio
# - best countries ranked in terms of their university having the best international students ratio
# - best regions ranked in terms of their university having the best student per faculty member ratio
# - best regions ranked in terms of their university having the best international students ratio

# %%
print("")
print_best_university_with_ratio(top_univ_df_with_ratios, "student_faculty_ratio","The best university in term of ratio between faculty members and students is")
print("\n\n")
print_best_university_with_ratio(top_univ_df_with_ratios, "inter_students_ratio","The best university in term of  ratio of international students is", ascending=False)

top_univ_df_with_ratios_by_country = top_univ_df_with_ratios.groupby("country") 
top_univ_df_with_ratios_by_region = top_univ_df_with_ratios.groupby("region") 

print("\n\n")
print_best_university_with_ratio_grouped(top_univ_df_with_ratios_by_country, "country", "student_faculty_ratio", True, "The best university in term of ratio between faculty members and students per country are")
print("\n\n")
print_best_university_with_ratio_grouped(top_univ_df_with_ratios_by_country, "country", "inter_students_ratio", False, "The best university in term of  ratio of international students per country are")

print("\n\n")
print_best_university_with_ratio_grouped(top_univ_df_with_ratios_by_region, "region", "student_faculty_ratio", True, "The best university in term of ratio between faculty members and students per region are")
print("\n\n")
print_best_university_with_ratio_grouped(top_univ_df_with_ratios_by_region, "region", "inter_students_ratio", False, "The best university in term of  ratio of international students per region are")

# %% [markdown]
# ## Question 2
# As for question 1, timeshighereducation.com has a JSON file that contains pretty much all the data we need. But since this file doesn't specify the university's by region like topuniversities.com does, we have to infer the region from the country. To do that, we create a dictionnary of country-region pair from the previous dataset. This time, the student-to-faculty ratio and international students ration are directly available, so there's no need to compute them. All the other steps are pretty much the same as for question 1.

# %%
TIMES_HIGHER_DATA = "https://www.timeshighereducation.com/sites/default/files/the_data_rankings/world_university_rankings_2018_limit0_369a9045a203e176392b9fb8f8c1cb2a.json"

# Loads JSON files containing universities data
th_data = json.loads(requests.get(TIMES_HIGHER_DATA).text)

# %%
# Creates a dictionnary of country-region pairs from the topuniversities.com dataset
map_country_region = top_univ_df[['country', 'region']].groupby('country').agg(lambda x:x.value_counts().index[0])
map_country_region = map_country_region.T.to_dict('list')

# Add missing value
map_country_region['Luxembourg'] = ['Europe']

# %% [markdown]
# Here function th_get_university_info is comparable to the one implement for retreiving data in question 1 but with some adaptations

# %%
def parse_percentage(string):
    """Parse a string representing a percentage as a float"""
    return float(string.strip('%'))/100

def th_get_university_info(raw_university):
    """Extract the relevent university info from the raw university data"""
    
    name = raw_university["aliases"]
    rank = raw_university["rank"].strip('=')
    country = raw_university["location"]
    if country=='Russian Federation':
        country = 'Russia'
        
    region = map_country_region[country][0]
    
    total_students = parse_int(raw_university["stats_number_students"])
    inter_students_ratio = parse_percentage(raw_university["stats_pc_intl_students"])
    student_faculty_ratio = (float)(raw_university["stats_student_staff_ratio"])
    
    
    return [name, rank, country, region, total_students, inter_students_ratio, student_faculty_ratio]

# %% [markdown]
# same as in exercise 1

# %%
th_univ_list = []

# Extract data for all universities
for i, raw_university in enumerate(th_data["data"][0:200]):
    print(i, end="\r")
    th_univ_list.append(th_get_university_info(raw_university))
    
        
times_higher_df = pd.DataFrame(th_univ_list, columns=["name", "rank", "country", "region", "total_students", "inter_students_ratio", "student_faculty_ratio"])
# Out:
# 199

# %% [markdown]
# The graphs are exactly the same as in exercise 1:
# - best universities in terms of students per faculty member
# - best universities in terms of international students
# - best countries ranked in terms of their university having the best student per faculty member ratio
# - best countries ranked in terms of their university having the best international students ratio
# - best regions ranked in terms of their university having the best student per faculty member ratio
# - best regions ranked in terms of their university having the best international students ratio

# %%
print_best_university_with_ratio(times_higher_df, "student_faculty_ratio", "The best universities in term of ratio between faculty members and students is")
print("\n\n")
print_best_university_with_ratio(times_higher_df, "inter_students_ratio", "The best university in term of  ratio of international students is", ascending=False)

times_higher_df_country = times_higher_df.groupby("country") 
times_higher_df_region = times_higher_df.groupby("region") 

print("\n\n")
print_best_university_with_ratio_grouped(times_higher_df_country, "country", "student_faculty_ratio", True, "The best university in term of ratio between faculty members and students per country are")
print("\n\n")
print_best_university_with_ratio_grouped(times_higher_df_country, "country", "inter_students_ratio", False, "The best university in term of  ratio of international students per country are")

print("\n\n")
print_best_university_with_ratio_grouped(times_higher_df_region, "region", "student_faculty_ratio", True, "The best university in term of ratio between faculty members and students per region are")
print("\n\n")
print_best_university_with_ratio_grouped(times_higher_df_region, "region", "inter_students_ratio", False, "The best university in term of  ratio of international students per region are")

# %% [markdown]
# ## Question 3
# In order to match the universities betwen the two rankings, the idea is to compute the string similarity of the university names using SequenceMatcher(...).ratio(). But since it would be too costly to compute the string similarity between all university pairs, we only compute it for universities that are in the same country.
#
# We also have to take into account that some universities may appear in one ranking and not the other. Thus, for each university in the first dataframe, we select the one from the second dataframe that has the highest name similarity, and we match them only if their similarity is higher that a certain threshold.
#
# One more thing we have to pay attention to is that each university has at most one match. This is done by storing the index of the matched universities from the second dataframe, and by checking when we have a match that they were not already matched.
#
# In order to further optimize the algorithm, we pre-process the university names before matching and remove each occurence of "University". Indeed, as this word appears very often in the names, it shouldn't be relevant to the similarity of two universities.

# %%
times_higher_df = pd.read_csv("times_higher_df.csv", index_col=False, usecols=range(1, 8))

# %%
from difflib import SequenceMatcher

def str_simil(a, b):
    return SequenceMatcher(None, a, b).ratio()

uni_1 = 'California Institute of Technology caltech'
uni_2 = 'California Institute of Technology (Caltech)'
#str_corr(uni_1, uni_2)

def match_universities(df1, df2):
    """Match the universities of the 2 dataframes based on the name and country.
       Returns a list of tuples corresponding to the indices of the 2 matched universities"""
    # Match is decided if the string similarity >= threshold
    threshold = 0.75
    
    df1 = df1.copy()
    df2 = df2.copy()
    
    # Remove common words (e.g. University) from all names. This would add irrelevant similarity if kept.
    df1.loc[:,'name'] = df1['name'].apply(lambda n: n.replace('University', ''))
    df2.loc[:,'name'] = df2['name'].apply(lambda n: n.replace('University', ''))
    
    matches = []
    already_matched = []
    for i1, row1 in df1.iterrows():
        max_simil = 0
        indices = (None, None)
        
        # Find best university match in the second dataframe
        for i2, row2 in df2.iterrows():
            if(row1['country'] == row2['country']) and i2 not in already_matched:
                # Compute string similarity between the two names
                simil = str_simil(row1['name'], row2['name'])
                #print([row1['name'], row2['name'], max_simil])
                
                if simil > max_simil:
                    max_simil = simil
                    indices = (i1, i2)
        
        # Decide that they match if the similarity is higher than some threshold
        if max_simil >= threshold:
            #print([top_univ_df.get_value(indices[0],'name'), times_higher_df.get_value(indices[1],'name'), max_simil])
            matches.append(indices)
            already_matched.append(indices[1])
        else:
            if indices[0] != None and indices[1] != None: 
                pass
                #print([top_univ_df.get_value(indices[0],'name'), times_higher_df.get_value(indices[1],'name'), max_simil])
            
    return matches

def rename_matching_universities(df1, df2, matches):
    """Rename universities of the second dataframe to have the same name as their match in the first dataframe"""
    for match in matches:
        name = df1.get_value(match[0],'name')
        df2.at[match[1], 'name'] = name

    return (df1, df2)

# %%
df1 = top_univ_df_with_ratios.copy()
df2 = times_higher_df.copy()
matches = match_universities(df1, df2)

df1, df2 = rename_matching_universities(df1, df2, matches)

# %%
merged_df = df1[["name", "rank", "country", "region", "student_faculty_ratio", "inter_students_ratio"]].merge(
    df2[["name", "rank", "student_faculty_ratio", "inter_students_ratio"]], how="inner", on="name")
merged_df
# Out:
#                                                   name  rank_x  \
# 0         Massachusetts Institute of Technology (MIT)        1
# 1                                  Stanford University       2
# 2                                   Harvard University       3
# 3         California Institute of Technology (Caltech)       4
# 4                              University of Cambridge       5
# 5                                 University of Oxford       6
# 6                      UCL (University College London)       7
# 7                              Imperial College London       8
# 8                                University of Chicago       9
# 9    ETH Zurich - Swiss Federal Institute of Techno...      10
# 10   Nanyang Technological University, Singapore (NTU)      11
# 11     Ecole Polytechnique Fédérale de Lausanne (EPFL)      12
# 12                                Princeton University      13
# 13                                  Cornell University      14
# ...

# %% [markdown]
# ## Question 4

# %%
plt.figure(figsize=(12,6))
plt.subplot(1, 2, 1)
x = merged_df['rank_x']
y = merged_df['student_faculty_ratio_x']
#m, b = np.polyfit(x, y, 1)
plt.plot(x, y, '.')
#plt.plot(x, m*x + b, '-')
plt.title("Top Universities")
plt.ylabel('Nb of students per faculty member')
plt.xlabel('University rank')

plt.subplot(1, 2, 2)
plt.plot(merged_df['rank_y'], merged_df['student_faculty_ratio_y'], '.')
plt.title("Times Higher Education")
plt.ylabel('Nb of students per faculty member')
plt.xlabel('University rank')
plt.tight_layout()
plt.show()

plt.figure(figsize=(12,6))
plt.subplot(1, 2, 1)
plt.plot(merged_df['rank_x'], merged_df['inter_students_ratio_x'], '.')
plt.title("Top Universities")
plt.ylabel('Proportion of international students')
plt.xlabel('University rank')

plt.subplot(1, 2, 2)
plt.plot(merged_df['rank_y'], merged_df['inter_students_ratio_y'], '.')
plt.title("Times Higher Education")
plt.ylabel('Proportion of international students')
plt.xlabel('University rank')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.subplot(1, 2, 1)
plt.plot(merged_df['rank_x'], merged_df['rank_y'], '.')
plt.title("Ranking Comparison")
plt.ylabel('Times Higher Education Rank')
plt.xlabel('Top Universities Rank')
plt.tight_layout()
plt.show()

# %%
# Plot total_students vs inter_students_ratio
plt.figure(figsize=(12,6))
plt.subplot(1, 2, 1)
plt.plot(top_univ_df_with_ratios['total_students'], top_univ_df_with_ratios['inter_students_ratio'], '.')
plt.title("Top Universities")
plt.ylabel('Proportion of international students')
plt.xlabel('Number of students')

plt.subplot(1, 2, 2)
plt.plot(times_higher_df['total_students'], times_higher_df['inter_students_ratio'], '.')
plt.title("Times Higher Education")
plt.ylabel('Proportion of international students')
plt.xlabel('Number of students')
plt.tight_layout()
plt.show()

# Plot total_students vs student_faculty_ratio
plt.figure(figsize=(12,6))
plt.subplot(1, 2, 1)
plt.plot(top_univ_df_with_ratios['total_students'], top_univ_df_with_ratios['student_faculty_ratio'], '.')
plt.title("Top Universities")
plt.ylabel('Nb of students per faculty member')
plt.xlabel('Number of students')

plt.subplot(1, 2, 2)
plt.plot(times_higher_df['total_students'], times_higher_df['student_faculty_ratio'], '.')
plt.title("Times Higher Education")
plt.ylabel('Nb of students per faculty member')
plt.xlabel('Number of students')
plt.tight_layout()
plt.show()

# Plot total_students vs rank
plt.figure(figsize=(12,6))
plt.subplot(1, 2, 1)
plt.plot(top_univ_df_with_ratios['total_students'], top_univ_df_with_ratios['rank'], '.')
plt.title("Top Universities")
plt.ylabel('Rank')
plt.xlabel('Number of students')

plt.subplot(1, 2, 2)
plt.plot(times_higher_df['total_students'], times_higher_df['rank'], '.')
plt.title("Times Higher Education")
plt.ylabel('Rank')
plt.xlabel('Number of students')
plt.tight_layout()
plt.show()

times_higher_df.corr()
# Out:
#                            rank  total_students  inter_students_ratio  \
# rank                   1.000000       -0.151891             -0.214197
# total_students        -0.151891        1.000000             -0.289970
# inter_students_ratio  -0.214197       -0.289970              1.000000
# student_faculty_ratio  0.107456        0.257120             -0.120413
#
#                        student_faculty_ratio
# rank                                0.107456
# total_students                      0.257120
# inter_students_ratio               -0.120413
# student_faculty_ratio               1.000000

# %% [markdown]
# # Question 4 Bruno

# %%
merged = df1.merge(df2, how="inner", on="name")
merged
# Out:
#                                                   name  rank_x  \
# 0         Massachusetts Institute of Technology (MIT)        1
# 1                                  Stanford University       2
# 2                                   Harvard University       3
# 3         California Institute of Technology (Caltech)       4
# 4                              University of Cambridge       5
# 5                                 University of Oxford       6
# 6                      UCL (University College London)       7
# 7                              Imperial College London       8
# 8                                University of Chicago       9
# 9    ETH Zurich - Swiss Federal Institute of Techno...      10
# 10   Nanyang Technological University, Singapore (NTU)      11
# 11     Ecole Polytechnique Fédérale de Lausanne (EPFL)      12
# 12                                Princeton University      13
# 13                                  Cornell University      14
# ...

# %% [markdown]
# Here is a table describing how columns are correlated with each other. Let's see what it tells us:

# %%
merged.corr()
# Out:
#                            rank_x  inter_staff  total_staff  inter_students  \
# rank_x                   1.000000    -0.504502    -0.374199       -0.252649
# inter_staff             -0.504502     1.000000     0.652026        0.582015
# total_staff             -0.374199     0.652026     1.000000        0.422447
# inter_students          -0.252649     0.582015     0.422447        1.000000
# total_students_x        -0.020269     0.276011     0.581218        0.630275
# student_faculty_ratio_x  0.354043    -0.311722    -0.327428        0.272917
# inter_students_ratio_x  -0.301594     0.387503    -0.066852        0.534463
# rank_y                   0.715818    -0.395646    -0.376548       -0.263612
# total_students_y        -0.024497     0.267896     0.599002        0.586239
# inter_students_ratio_y  -0.283154     0.329408    -0.110594        0.416462
# student_faculty_ratio_y  0.241544    -0.014265    -0.077532        0.314445
#
# ...

# %% [markdown]
# Of course each column is totally correlated to itself, that's why we have these diagonal 1s.
#
# Then it is also quite evident that the 2 columns representing the number of students are highly correlated because data is from the same school year. The same reason is valid for the columns representing the internationnal student ratios.

# %%
plt.figure(figsize=(12,6))
plt.subplot(1, 2, 1)
plt.plot(merged['total_students_x'], merged['total_students_y'], '.')
plt.title("Number of students in both rankings")
plt.ylabel('Times Higher Education')
plt.xlabel('Top Universities')

plt.subplot(1, 2, 2)
plt.plot(merged['inter_students_ratio_x'], merged['inter_students_ratio_y'], '.')
plt.title("Proportion of international students in both rankings")
plt.ylabel('Times Higher Education')
plt.xlabel('Top Universities')
plt.tight_layout()
plt.show()

# %% [markdown]
# Another correlation we could expect is the one between the two columns of rank: when a university is well ranked in one ranking, it is also well ranking in the other ranking.

# %%
# Plot ranking comparison
plt.figure(figsize=(12,6))
plt.subplot(1, 2, 1)
plt.plot(merged['rank_x'], merged['rank_y'], '.')
plt.title("Ranking Comparison")
plt.ylabel('Times Higher Education Rank')
plt.xlabel('Top Universities Rank')
plt.tight_layout()
plt.show()

# %% [markdown]
# There are still a few less obvious correlations, such as:
# - When there is a lot of staff, there also is a larger proportion of internationnal staff (correlation of 0.65)
# - When a university has a lot of internationnal staff, it has quite a good ranking (correlation of 0.50)
# - We can see that when the university has a lot of internationnal sudents, it also has a lot of internationnal staff (correlation of 0.58)
# - When there are a lot of students in a university, the number of students per staff member is also higher (0.58)
# - ...
#
# In fact everytime the correlation between 2 columns is in [-1;-0.5]U[0.5;1], this mean that the probability they are correlatedd is high.

# %%
# Plot proportion of international staff vs total number of staff
plt.figure(figsize=(12,12))
plt.subplot(2, 2, 1)
plt.plot(merged['total_staff'], merged['inter_staff'], '.')
plt.title("Proportion of international staff vs total number of staff")
plt.ylabel('Proportion of international staff')
plt.xlabel('Number of staff members')

# Plot number of international staff vs ranking
plt.subplot(2, 2, 2)
plt.plot(merged['rank_x'], merged['inter_staff'], '.')
plt.title("Number of international staff vs total number of staff")
plt.ylabel('Number of international staff')
plt.xlabel('Top Universities Ranking')

# Plot number of international staff vs number of international students
plt.subplot(2, 2, 3)
plt.plot(merged['inter_students'], merged['inter_staff'], '.')
plt.title("Number of international staff vs number of international students")
plt.ylabel('Number of international staff')
plt.xlabel('Number of international students')
plt.tight_layout()
plt.show()

# Plot total_students vs student_faculty_ratio
plt.figure(figsize=(12,6))
plt.subplot(1, 2, 1)
plt.plot(top_univ_df_with_ratios['total_students'], top_univ_df_with_ratios['student_faculty_ratio'], '.')
plt.title("Top Universities")
plt.ylabel('Nb of students per faculty member')
plt.xlabel('Number of students')

plt.subplot(1, 2, 2)
plt.plot(times_higher_df['total_students'], times_higher_df['student_faculty_ratio'], '.')
plt.title("Times Higher Education")
plt.ylabel('Nb of students per faculty member')
plt.xlabel('Number of students')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Question 5

# %%
merged_rank = df1[["name", "rank"]].merge(df2[["name", "rank"]], how="inner", on="name")
merged_rank
# Out:
#                                                   name  rank_x  rank_y
# 0         Massachusetts Institute of Technology (MIT)        1       5
# 1                                  Stanford University       2       3
# 2                                   Harvard University       3       6
# 3         California Institute of Technology (Caltech)       4       3
# 4                              University of Cambridge       5       2
# 5                                 University of Oxford       6       1
# 6                      UCL (University College London)       7      16
# 7                              Imperial College London       8       8
# 8                                University of Chicago       9       9
# 9    ETH Zurich - Swiss Federal Institute of Techno...      10      10
# 10   Nanyang Technological University, Singapore (NTU)      11      52
# 11     Ecole Polytechnique Fédérale de Lausanne (EPFL)      12      38
# ...

# %%
def rank_score_square_mean(col1, col2):
    return np.sqrt((col1)**2 + (col2)**2)

def rank_score_harmonic_mean(col1,col2):
    return 2/((1/col1)+(1/col2))

# %%
def overall_rank():
    overall_rank = []
    for i in range(1,142):
        overall_rank.append(i)
    return overall_rank

# %%
rank_score_harmonic = rank_score_harmonic_mean(merged_rank.rank_x,merged_rank.rank_y)
rank_score_harmonic_df = append_column_to_dataframe(merged_rank, rank_score_harmonic, "rank_score").sort_values("rank_score", ascending=True)
rank_score_harmonic_df = append_column_to_dataframe(rank_score_harmonic_df, overall_rank(), "overall_rank")
rank_score_harmonic_df
# Out:
#                                                   name  rank_x  rank_y  \
# 0         Massachusetts Institute of Technology (MIT)        1       5
# 5                                 University of Oxford       6       1
# 1                                  Stanford University       2       3
# 4                              University of Cambridge       5       2
# 3         California Institute of Technology (Caltech)       4       3
# 2                                   Harvard University       3       6
# 7                              Imperial College London       8       8
# 8                                University of Chicago       9       9
# 12                                Princeton University      13       7
# 6                      UCL (University College London)       7      16
# 9    ETH Zurich - Swiss Federal Institute of Techno...      10      10
# 18                          University of Pennsylvania      19      10
# ...

# %%
rank_score_square = rank_score_square_mean(merged_rank.rank_x,merged_rank.rank_y)
rank_score_square_df = append_column_to_dataframe(merged_rank, rank_score_square, "rank_score").sort_values("rank_score", ascending=True)
rank_score_square_df = append_column_to_dataframe(rank_score_square_df, overall_rank(), "overall_rank")
rank_score_square_df
# Out:
#                                                   name  rank_x  rank_y  \
# 1                                  Stanford University       2       3
# 3         California Institute of Technology (Caltech)       4       3
# 0         Massachusetts Institute of Technology (MIT)        1       5
# 4                              University of Cambridge       5       2
# 5                                 University of Oxford       6       1
# 2                                   Harvard University       3       6
# 7                              Imperial College London       8       8
# 8                                University of Chicago       9       9
# 9    ETH Zurich - Swiss Federal Institute of Techno...      10      10
# 12                                Princeton University      13       7
# 6                      UCL (University College London)       7      16
# 15                                     Yale University      16      12
# ...

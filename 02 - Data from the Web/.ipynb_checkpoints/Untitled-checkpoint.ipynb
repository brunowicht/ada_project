# %%
import requests
from bs4 import BeautifulSoup
import json
import pandas as pd

# %%
TOP_UNIV_BASE = "https://www.topuniversities.com"
TOP_UNIV_WEBSITE = "https://www.topuniversities.com/university-rankings/world-university-rankings/2018"
TOP_UNIV_DATA_INDICATOR = "https://www.topuniversities.com/sites/default/files/qs-rankings-data/357051_indicators.txt"

# %%
r = requests.get(TOP_UNIV_WEBSITE)
data_indicator = requests.get(TOP_UNIV_DATA_INDICATOR)

soup = BeautifulSoup(r.text, 'html.parser')
indicator_data = json.loads(data_indicator.text)

# %%
def parse_int(string):
    tmp = string.replace(',', '')
    return int(tmp)
    
def get_university_info_from_indicator(raw_university):
    overview_soup = BeautifulSoup(raw_university["uni"], 'html.parser')    
    
    name = overview_soup.a.text
    rank = raw_university["overall_rank"]
    region = raw_university["region"]
    country = raw_university["location"]
    
    details_request = requests.get(TOP_UNIV_BASE + "/" +  overview_soup.a.attrs['href'])
    details_soup = BeautifulSoup(details_request.text, 'html.parser')
        
    total_staff = parse_int(details_soup.find("div", {"class": "total faculty"}).find("div", {"class" : "number"}).text)
    inter_staff = parse_int(details_soup.find("div", {"class": "inter faculty"}).find("div", {"class" : "number"}).text)
    total_students = parse_int(details_soup.find("div", {"class": "total student"}).find("div", {"class": "number"}).text)
    inter_students = parse_int(details_soup.find("div", {"class": "total inter"}).find("div", {"class": "number"}).text)
    
    return [name, rank, country, region, inter_staff, total_staff, inter_students, total_students]

# %%
univ_list = []

for i, raw_university in enumerate(indicator_data["data"][0:200]):
    print(i, end="\r")
    try:
        univ_list.append(get_university_info_from_indicator(raw_university))
    except:
        pass
        
top_univ_df = pd.DataFrame(univ_list, columns=["name", "rank", "country", "region", "inter_staff", "total_staff", "inter_students", "total_students"])
# Out:
# 109

# %%
top_univ_df

# %%
top_univ_df.to_csv("top_univ_df.csv")

# %%
top_univ_df = pd.read_csv("top_univ_df.csv", index_col=False, usecols=range(1, 9))

# %%
def print_best_university_with_ratio(ratio_df): 
    sorted_ratio = ratio_df.sort_values()
    best_entry = top_univ_df.loc[[sorted_ratio.index[0]]]#(tmp[0])
    best_entry.loc[:,'ratio'] = sorted_ratio[0]
    display(best_entry)

ratio_a = top_univ_df.total_staff / (top_univ_df.total_students + top_univ_df.total_staff)
ratio_b = top_univ_df.inter_students / top_univ_df.total_students

print("The best university in term of ratio between faculty members and students is")
print_best_university_with_ratio(ratio_a)
print("\n\nThe best university in term of  ratio of international students is")
print_best_university_with_ratio(ratio_b)
# Out:
# The best university in term of ratio between faculty members and students is
#                                 name  rank  country  region  inter_staff  \
# 180  Vienna University of Technology   182  Austria  Europe          172
#
#      total_staff  inter_students  total_students     ratio
# 180          706            5199           17479  0.212257
# The best university in term of  ratio of international students is
#                                              name  rank country region  \
# 177  Indian Institute of Technology Bombay (IITB)   179   India   Asia
#
#      inter_staff  total_staff  inter_students  total_students     ratio
# 177           19          876              93            9402  0.335863

# %%
ratio_d = top_univ_df.groupby(top_univ_df.region)

top_univ_df_with_ratio_a = top_univ_df.copy()
top_univ_df_with_ratio_a.loc[:, "ratio"] = ratio_a

top_univ_df_with_ratio_b = top_univ_df.copy()
top_univ_df_with_ratio_b.loc[:, "ratio"] = ratio_b

ratio_c_a = top_univ_df_with_ratio_a.groupby(top_univ_df_with_ratio_a.country)
ratio_c_b = top_univ_df_with_ratio_b.groupby(top_univ_df_with_ratio_b.region)

display(ratio_c_a.get_group("Austria"))
display(ratio_c_a.max())
#display(ratio_c_b.max("ratio"))
# Out:
#                                 name  rank  country  region  inter_staff  \
# 152             University of Vienna   154  Austria  Europe         1400
# 180  Vienna University of Technology   182  Austria  Europe          172
#
#      total_staff  inter_students  total_students     ratio
# 152         3411           14468           45967  0.069079
# 180          706            5199           17479  0.038823
#                                                              name  rank  \
# country
# Argentina                       Universidad de Buenos Aires (UBA)    75
# Australia                         University of Technology Sydney   176
# Austria                           Vienna University of Technology   182
# Belgium                          Vrije Universiteit Brussel (VUB)   182
# Brazil                                  Universidade de São Paulo   182
# Canada                                    Université de Montréal    152
# Chile               Pontificia Universidad Católica de Chile (UC)   137
# China                                         Zhejiang University   114
# Denmark                                  University of Copenhagen   119
# Finland                                    University of Helsinki   137
# France                           École Normale Supérieure de Lyon   177
# Germany                                   University of Göttingen   281
# Hong Kong                             The University of Hong Kong    95
# India                 Indian Institute of Technology Delhi (IITD)   179
# Ireland                                 University College Dublin   168
# Israel                         The Hebrew University of Jerusalem   145
# Italy           Scuola Superiore Sant'Anna Pisa di Studi Unive...   192
# Japan                               Tokyo Institute of Technology   192
# Malaysia                                   Universiti Malaya (UM)   114
# Mexico            Universidad Nacional Autónoma de México  (UNAM)   199
# Netherlands                                 Wageningen University   200
# New Zealand                                   University of Otago   151
# Norway                                         University of Oslo   164
# Russia                          Lomonosov Moscow State University    95
# Saudi Arabia         King Fahd University of Petroleum & Minerals   173
# Singapore                  National University of Singapore (NUS)    15
# South Africa                              University of Cape Town   191
# South Korea                                     Yonsei University   155
# Spain                                    Universitat de Barcelona   195
# Sweden                                         Uppsala University   195
# Switzerland                                  University of Zurich   167
# Taiwan                              National Tsing Hua University   161
# United Kingdom                                 University of York   188
# United States                                     Yale University   195
#
#                        region  inter_staff  total_staff  inter_students  \
# country
# Argentina       Latin America         3165        16421           27109
# Australia             Oceania         1870         3360           20578
# Austria                Europe         1400         3411           14468
# Belgium                Europe          784         2520            6926
# Brazil          Latin America          279         5582            2086
# Canada          North America         3905         9581           21910
# Chile           Latin America          198         2260             991
# China                    Asia         1913         5506            7090
# Denmark                Europe         2336         7483            3762
# Finland                Europe          535         2645            1831
# France                 Europe          259         2273            4213
# Germany                Europe         1174         5850            8556
# Hong Kong                Asia         2085         3012            8230
# India                    Asia           19          876              93
# Ireland                Europe          627         1604            4311
# Israel                   Asia          454         2249            1034
# Italy                  Europe          231         2990            5593
# Japan                    Asia          296         4514            2639
# Malaysia                 Asia          655         2755            3476
# Mexico          Latin America          949        15073            2173
# Netherlands            Europe         1137         3351           10780
# New Zealand           Oceania          759         2047            8568
# Norway                 Europe          711         2509            3667
# Russia                 Europe          373         6709            5098
# Saudi Arabia             Asia          665         1062             989
# Singapore                Asia         3086         5106            8917
# South Africa           Africa          379         1733            3325
# South Korea              Asia          433         3930            3638
# Spain                  Europe          230         3863            6134
# Sweden                 Europe         1002         3031            6408
# Switzerland            Europe         2617         4997            7563
# Taiwan                   Asia          220         2807            3152
# United Kingdom         Europe         2964         6750           14854
# United States   North America         2042         6809            9483
#
#                 total_students     ratio
# country
# Argentina               122301  0.118373
# Australia                57433  0.099738
# Austria                  45967  0.069079
# Belgium                  45538  0.161791
# Brazil                   65711  0.078297
# Canada                   72207  0.119964
# Chile                    27003  0.077231
# China                    42136  0.131704
# Denmark                  32119  0.192542
# Finland                  22419  0.105530
# France                   24305  0.171921
# Germany                  44517  0.131237
# Hong Kong                20972  0.129682
# India                     9402  0.085231
# Ireland                  19833  0.077051
# Israel                   16531  0.119755
# Italy                    63399  0.139159
# Japan                    33500  0.160608
# Malaysia                 17902  0.133369
# Mexico                  141939  0.119884
# Netherlands              31754  0.152084
# New Zealand              29641  0.064599
# Norway                   24304  0.124179
# Russia                   30233  0.181609
# Saudi Arabia              6040  0.149535
# Singapore                32728  0.144235
# South Africa             19593  0.081262
# South Korea              28064  0.175615
# Spain                    46002  0.093610
# Sweden                   28281  0.105947
# Switzerland              26065  0.160872
# Taiwan                   32195  0.080195
# United Kingdom           36670  0.255006
# United States            60294  0.297070
